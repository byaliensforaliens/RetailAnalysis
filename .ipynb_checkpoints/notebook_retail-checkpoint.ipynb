# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import OrdinalEncoder
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# # Data Exploration

# %%
df = pd.read_csv("../Data/online_retail_II.csv")
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    5918
# REGENCY CAKESTAND 3 TIER              4412
# JUMBO BAG RED RETROSPOT               3469
# ASSORTED COLOUR BIRD ORNAMENT         2958
# PARTY BUNTING                         2765
#                                       ...
# code mix up? 84930                       1
# PINK HEART CHRISTMAS DECORATION          1
# water damaged                            1
# Came as green?                           1
# damges                                   1
# Name: Description, Length: 5698, dtype: int64

# %%
df['Description'].nunique()
# Out:
# 5698

# %%
df.drop('Description',1,inplace=True)

# %%
list(df.columns)
# Out:
# ['Invoice',
#  'StockCode',
#  'Quantity',
#  'InvoiceDate',
#  'Price',
#  'Customer ID',
#  'Country']

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          981330
# EIRE                     17866
# Germany                  17624
# France                   14330
# Netherlands               5140
# Spain                     3811
# Switzerland               3189
# Belgium                   3123
# Portugal                  2620
# Australia                 1913
# Channel Islands           1664
# Italy                     1534
# Norway                    1455
# Sweden                    1364
# Cyprus                    1176
# Finland                   1049
# Austria                    938
# Denmark                    817
# Unspecified                756
# Greece                     663
# Japan                      582
# Poland                     535
# USA                        535
# United Arab Emirates       500
# Israel                     371
# Hong Kong                  364
# Singapore                  346
# Malta                      299
# Iceland                    253
# Canada                     228
# Lithuania                  189
# RSA                        169
# Bahrain                    126
# Brazil                      94
# Thailand                    76
# Korea                       63
# European Community          61
# Lebanon                     58
# West Indies                 54
# Bermuda                     34
# Nigeria                     32
# Czech Republic              30
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
df.dtypes
# Out:
# Invoice                object
# StockCode              object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
df['Customer ID'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df['Customer ID'] = df['Customer ID'].apply(lambda x: int(x))

# %% [markdown]
# # Sales Analysis by Product, Country, Invoice and Customer

# %%
df.sample(20)
# Out:
#         Invoice StockCode  Quantity         InvoiceDate  Price  Customer ID  \
# 913751   570423     22326         4 2011-10-10 13:38:00   2.95        14451
# 973512   575007     22577        24 2011-11-08 11:20:00   0.29        14140
# 961015   574076     21824        21 2011-11-02 15:38:00   0.83            0
# 20134    491041     84375         4 2009-12-09 09:42:00   4.30            0
# 1025411  578702     22847         2 2011-11-25 10:58:00  16.95        15382
# 184309   506951    47599A         6 2010-05-05 11:36:00   2.10        14560
# 973842   575051     22144         6 2011-11-08 12:14:00   2.10        15957
# 529519   536745    85184C        12 2010-12-02 13:38:00   2.95        17235
# 87764    497592     22382        50 2010-02-11 08:51:00   1.65        17139
# 406343   528324     21056         3 2010-10-21 13:02:00   8.95        13092
# 341579   522739     20751         1 2010-09-16 13:06:00   2.10        14963
# 76788    496349     48189         2 2010-02-01 08:13:00   6.75        14739
# 980649   575607     35971         2 2011-11-10 12:37:00   2.46        14096
# 1061128  581217     22643         2 2011-12-08 09:20:00   4.96            0
# 984099   575846     23245         3 2011-11-11 12:07:00   4.95        17364
# 864282   566566     84347         1 2011-09-13 12:32:00   4.96        14096
# 96625    498493       DOT         1 2010-02-19 11:03:00  45.36            0
# 337263   522281    85014A         1 2010-09-13 12:56:00   5.95        16374
# 23959    491345    79323P         1 2009-12-10 15:46:00   6.75            0
# 117749   500577    72083A         2 2010-03-08 17:27:00   2.10        17222
#
#                 Country
# 913751   United Kingdom
# 973512   United Kingdom
# 961015   United Kingdom
# 20134    United Kingdom
# 1025411  United Kingdom
# 184309   United Kingdom
# 973842   United Kingdom
# 529519   United Kingdom
# 87764    United Kingdom
# 406343   United Kingdom
# 341579   United Kingdom
# 76788    United Kingdom
# 980649   United Kingdom
# 1061128  United Kingdom
# 984099   United Kingdom
# 864282   United Kingdom
# 96625    United Kingdom
# 337263   United Kingdom
# 23959    United Kingdom
# 117749   United Kingdom

# %% [markdown]
# # Clustering and Segmentation by Sales

# %%
X = df.sample(5000)

# %%
X.head()
# Out:
#        Invoice StockCode  Quantity         InvoiceDate  Price  Customer ID  \
# 139802  502771     22333        48 2010-03-26 14:29:00   1.45        13694
# 710669  552769    85099B         1 2011-05-11 11:47:00   2.08        16241
# 356219  523994     22511         1 2010-09-26 15:07:00   3.75        16549
# 683183  550210     22698         1 2011-04-15 10:40:00   5.79            0
# 808215  561658     85212        12 2011-07-28 16:06:00   0.29        12743
#
#                Country
# 139802  United Kingdom
# 710669  United Kingdom
# 356219  United Kingdom
# 683183  United Kingdom
# 808215     Unspecified

# %%
ordinal_encoder = OrdinalEncoder()
countries = X['Country'].values.reshape(-1,1)
country_encoded = ordinal_encoder.fit_transform(countries)
X['Country'] = country_encoded

# %%
stock = X['StockCode'].values.reshape(-1,1)
stock_encoded = ordinal_encoder.fit_transform(stock)
X['StockCode'] = stock_encoded

# %%
invoice = X['Invoice'].values.reshape(-1,1)
invoice_encoded = ordinal_encoder.fit_transform(invoice)
X['Invoice'] = invoice_encoded

# %%
X.head()
# Out:
#         Invoice  StockCode  Quantity         InvoiceDate  Price  Customer ID  \
# 139802    516.0      803.0        48 2010-03-26 14:29:00   1.45        13694
# 710669   2731.0     1922.0         1 2011-05-11 11:47:00   2.08        16241
# 356219   1447.0      925.0         1 2010-09-26 15:07:00   3.75        16549
# 683183   2613.0     1064.0         1 2011-04-15 10:40:00   5.79            0
# 808215   3111.0     1973.0        12 2011-07-28 16:06:00   0.29        12743
#
#         Country
# 139802     27.0
# 710669     27.0
# 356219     27.0
# 683183     27.0
# 808215     28.0

# %%
def datetime_to_float(d):
    return d.timestamp()

X['InvoiceDate'] = X['InvoiceDate'].apply(datetime_to_float)

# %%
k = 5
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)

# %%
y_pred is kmeans.labels_
# Out:
# True

# %%
centroids = kmeans.cluster_centers_

# %%
kmeans.score(X)
# Out:
# -6.305288413170386e+16

# %%
sns.pairplot(X.assign(hue=labels), hue='hue')

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

ax = sns.scatterplot(X.iloc[:,0],X.iloc[:,1], hue=labels, alpha=0.5)
ax = sns.scatterplot(centroids[:, 0], centroids[:, 1],
                     hue=range(k), s=20, ec='black', legend=False, ax=ax)
plt.show()

# %%
variables = [z for z in X.columns.tolist() if z != 'Customer ID']
sns.pairplot(X.assign(hue=labels), hue='hue', x_vars=variables, y_vars=["Customer ID"])
